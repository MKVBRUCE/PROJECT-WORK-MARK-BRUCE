# %% [markdown]
# # MARK BRUCE
# ## 11331128
# ### MTEN DEPARTMENT

# %%
import numpy as np

# %%
import matplotlib as plt

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
import pandas as pd

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\user\\AppData\\Roaming\\Python\\Python311\\site-packages\\pandas\\__init__.py'>

# %%
dataset=pd.read_csv('red_wine.csv')

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
 dataset.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y=dataset.dropna()

# %%
y
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure
# Out:
# <function matplotlib.pyplot.figure(num: 'int | str | Figure | SubFigure | None' = None, figsize: 'tuple[float, float] | None' = None, dpi: 'float | None' = None, *, facecolor: 'ColorType | None' = None, edgecolor: 'ColorType | None' = None, frameon: 'bool' = True, FigureClass: 'type[Figure]' = <class 'matplotlib.figure.Figure'>, clear: 'bool' = False, **kwargs) -> 'Figure'>

# %%
import pandas as pd
plt.figure(figsize=(9,7))
dataset=pd.read_csv('red_wine.csv')
plt.hist(dataset['alcohol'],bins=20,color='red', edgecolor='yellow')
plt.title('ILLUSTRATION OF THE ALCOHOLIC CONTENT IN RED WINE')
plt.xlabel ('ALCOHOLIC CONTENT')
plt.ylabel ('Frequency')
plt.show()

# %%
plt.figure(figsize=(9,7))
plt.scatter(dataset['alcohol'], dataset['fixed acidity'], color='blue', edgecolor='black',)
plt.title('ALCOHOLIC CONTENT AGAINST FIXED ACIDITY IN RED WINE')
plt.xlabel('Alcoholic content')
plt.ylabel('fixed acidity')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['citric acid'],bins=20,color='yellow',edgecolor='black')
plt.title('Illustration of amount of citric acid in red wine')
plt.xlabel('Citric Acid Content')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(9,7))
plt.scatter(dataset['residual sugar'],dataset['sulphates'],color='brown')
plt.title('RESIDUAL SUGAR CONTENT AGAINST SULPHATES IN RED WINE')
plt.xlabel('Residual sugar content')
plt.ylabel('Sulphates')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure
plt.figure(figsize=(8,6))
import pandas as pd
pd
dataset=pd.read_csv('red_wine.csv')
plt.scatter(dataset['total sulfur dioxide'],dataset['pH'],color='orange')
plt.title('RELATIONSHIP OF TOTAL SULFUR DIOXIDE WITH pH of Red wine')
plt.xlabel('Total sulfur dioxide')
plt.ylabel('pH of red wine')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.hist(dataset['volatile acidity'], bins=20, color='green', edgecolor='black')
plt.title('Pictorial Illustration of Volatile acidity in red wine')
plt.xlabel('Volatile Acidity')
plt.ylabel('frequency')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(dataset['density'],dataset['quality'],color='black')
plt.title('Relationship between density and quality of red wine')
plt.xlabel('Density')
plt.ylabel('quality')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['free sulfur dioxide'], bins=20, color='skyblue', edgecolor='black')
plt.title ('SPREAD OF SULFUR DIOXIDE CONTENT IN RED WINE')
plt.xlabel('FREE SULFUR DIOXIDE CONTENT IN RED WINE ')
plt.ylabel ('Frequency')
plt.show()

# %% [markdown]
# # REPORT ON GRAPHS
# ## THE HISTOGRAMS SHOW OR ILLUSTRATE THE FREQUENCY OF A SET  OF  DATA IN  THE RED WINE USING VALUES
# ### This is shown with the histogram of the alcoholic content in the red wine, which peaks or is highest at a certain value  (350)
# ### The second histogram shows the citric acid content in the red wine. It peaks at a value of around 250.
# ### The third histogram shows the volatile acidity in the red wine. It has a peak value of around 280.
# ### The fourth histogram shows the distribution of free sulfur dioxides in the red wine. It peaks at a value just above 350.
# # THE SCATTER PLOTS ILLUSTRATE A CORRELATION OR RELATIONSHIP BETWEEN TWO SETS OF DATA
# ### The first scatter plot for a example, shows a possible correlation between alcoholic content and the fixed acidity in red wine, a cluster of dots can be seen in the middle, thus forming a pattern. Some outliers can be seen at the extreme left and right of the plot, showing a strong relationship between the two sets of data.
# ### The second scatter plot shows a relationship between residual sugar and sulphates in the red wine. A large number of dots can be seen in the far left of the plot, thus forming a cluster around that area. This shows that there is some kind of relationship between the two sets of data. Some outliers can be seen at the far right and the top left of the graph and they do not fit the patten of the data.
# ### The third scatter plot shows a relationship between total sulfur dioxide with the pH of red wine. Like the second scatter plot a pattern can be observed at the far left of graph, with several dots seen at that side of the graph. Some outliers which do not follow the pattern of the data can be seen at the far right of the graph.
# ### The fourth scatter illustrates the relationship between the quality and density of the red wine. A linear relationship can be seen all over the plot. This means that one variable or set of data will increase or decrease at a constant rate relative to the other set of data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
dataset=pd.read_csv('red_wine.csv')
plt.figure(figsize=(8,6))
plt.scatter(dataset['fixed acidity'], dataset['quality'], color='red')
